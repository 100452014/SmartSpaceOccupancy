# %% [markdown]
# # Open Data: extraction and transformation

# %%
import requests
import requests_cache
from retry_requests import retry
import pandas as pd
from datetime import datetime
pd.options.display.max_rows = 100
pd.options.display.max_columns = None

# %%
path = "OPEN_DATA_PATH"

# %% [markdown]
# ## Weather data from Open-Meteo
#
# https://open-meteo.com
#
# https://pypi.org/project/openmeteo-requests/

# %%
import openmeteo_requests

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after=3600)
retry_session = retry(cache_session, retries=5, backoff_factor=0.2)
openmeteo = openmeteo_requests.Client(session=retry_session)

# %% [markdown]
# Define the latitude and longitude provided by Habitat

# %%
latitude = 40.7
longitude = -3.5

# %%
def get_weather_df(url, params):
    
    responses = openmeteo.weather_api(url, params=params)
    
    response = responses[0]
    print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
    
    # Process daily data. The order of variables needs to be the same as requested.
    daily = response.Daily()
    daily_weather_code = daily.Variables(0).ValuesAsNumpy()
    daily_temperature_2m_max = daily.Variables(1).ValuesAsNumpy()
    daily_temperature_2m_min = daily.Variables(2).ValuesAsNumpy()
    daily_precipitation_sum = daily.Variables(3).ValuesAsNumpy()
    
    daily_data = {"date": pd.date_range(
    	start = pd.to_datetime(daily.Time(), unit = "s", utc = True),
    	end = pd.to_datetime(daily.TimeEnd(), unit = "s", utc = True),
    	freq = pd.Timedelta(seconds = daily.Interval()),
    	inclusive = "left"
    ), "weather_code": daily_weather_code, "temperature_2m_max": daily_temperature_2m_max,
        "temperature_2m_min": daily_temperature_2m_min, "precipitation_sum": daily_precipitation_sum}
    
    df = pd.DataFrame(data = daily_data)
    return df

# %% [markdown]
# ### Past forecast weather data
#
# https://open-meteo.com/en/docs/historical-forecast-api

# %%
url = "https://historical-forecast-api.open-meteo.com/v1/forecast"

# define desired interval of days
start_date = "2022-01-01"
end_date = datetime.now().strftime('%Y-%m-%d')

params = {
	"latitude": latitude,
	"longitude": longitude,
	"start_date": start_date,
	"end_date": end_date,
	"daily": ["weather_code", "temperature_2m_max", "temperature_2m_min", "precipitation_sum"]
}

past_df = get_weather_df(url,params)

past_df
# Out:
# Coordinates 40.70000076293945°N -3.5°E
#                          date  weather_code  temperature_2m_max  \
# 0   2022-01-01 00:00:00+00:00           3.0           15.602500
# 1   2022-01-02 00:00:00+00:00           3.0           14.302500
# 2   2022-01-03 00:00:00+00:00           3.0           13.102500
# 3   2022-01-04 00:00:00+00:00          80.0           11.752500
# 4   2022-01-05 00:00:00+00:00          51.0            7.952500
# ..                        ...           ...                 ...
# 838 2024-04-18 00:00:00+00:00           3.0           20.775999
# 839 2024-04-19 00:00:00+00:00           3.0           20.775999
# 840 2024-04-20 00:00:00+00:00           3.0           23.375999
# 841 2024-04-21 00:00:00+00:00           3.0           21.825998
# 842 2024-04-22 00:00:00+00:00           3.0           18.675999
#
#      temperature_2m_min  precipitation_sum
# 0                6.5025                0.0
# 1                6.8025                0.0
# 2                5.6525                0.0
# 3                4.6525                2.7
# 4                3.0025                0.6
# ..                  ...                ...
# 838              6.5760                0.0
# 839              4.5260                0.0
# 840              7.8760                0.0
# 841              8.4260                0.0
# 842              6.6760                0.0
#
# [843 rows x 5 columns]

# %% [markdown]
# ##### Data transformation

# %%
# Change date format
past_df['date'] = pd.to_datetime(past_df['date']).dt.strftime('%Y-%m-%d')
# Save results
past_df.to_csv(f"{path}pastWeather{start_date.replace('-','')}_{end_date.replace('-','')}.csv", index=False)

# %% [markdown]
# ### Future forecast weather data
#
# https://open-meteo.com/en/docs/

# %%
url = "https://api.open-meteo.com/v1/forecast"

params = {
    "latitude": latitude,
    "longitude": longitude,
    "daily": ["weather_code", "temperature_2m_max", "temperature_2m_min", "precipitation_sum"],
    "past_days": 0,
    "forecast_days": 16
}

forecast_df = get_weather_df(url,params)

forecast_df
# Out:
# Coordinates 40.70000076293945°N -3.5°E
#                         date  weather_code  temperature_2m_max  \
# 0  2024-04-22 00:00:00+00:00           3.0           19.675999
# 1  2024-04-23 00:00:00+00:00           3.0           17.075998
# 2  2024-04-24 00:00:00+00:00           3.0           20.580000
# 3  2024-04-25 00:00:00+00:00          51.0           15.280000
# 4  2024-04-26 00:00:00+00:00           3.0           16.068001
# 5  2024-04-27 00:00:00+00:00          80.0           12.818001
# 6  2024-04-28 00:00:00+00:00           3.0           14.218000
# 7  2024-04-29 00:00:00+00:00           3.0           16.602499
# 8  2024-04-30 00:00:00+00:00           1.0           18.802500
# 9  2024-05-01 00:00:00+00:00           3.0           21.602499
# 10 2024-05-02 00:00:00+00:00           3.0           23.802500
# 11 2024-05-03 00:00:00+00:00           3.0           24.202499
# 12 2024-05-04 00:00:00+00:00           3.0           25.802500
# 13 2024-05-05 00:00:00+00:00           3.0           26.052500
# 14 2024-05-06 00:00:00+00:00          51.0           22.352499
# 15 2024-05-07 00:00:00+00:00          51.0           15.202499
#
#     temperature_2m_min  precipitation_sum
# 0             6.676000                0.0
# 1             2.526000                0.0
# 2             2.976000                0.0
# 3             9.680000                0.8
# 4             5.368000                0.0
# 5             6.918000                4.5
# 6             3.268000                0.0
# 7             2.468000                0.0
# 8             5.052500                0.0
# 9             5.902500                0.0
# 10            8.052500                0.0
# 11           11.002500                0.0
# 12           12.002500                0.0
# 13           14.702499                0.0
# 14           10.102500                0.2
# 15            8.502500                0.4

# %% [markdown]
# ##### Data transformation

# %%
# Change date format
forecast_df['date'] = pd.to_datetime(forecast_df['date']).dt.strftime('%Y-%m-%d')
# Save results
forecast_df.to_csv(f"{path}forecastWeather{datetime.now().strftime('%Y%m%d')}.csv", index=False)

# %% [markdown]
# ## Holiday Calendar from Comunidad de Madrid
#
# https://datos.comunidad.madrid/catalogo/?q=festivos&sort=score+desc%2C+metadata_modified+desc

# %% [markdown]
# #### Transformation of Regional data

# %%
loc = pd.read_csv(path+"festivos_locales_historicos.csv", sep=';', encoding = 'latin-1')
loc
# Out:
#        año  municipio_codigo       municipio_nombre  entidad_codigo  \
# 0     1998                 2                Ajalvir               0
# 1     1998                 2                Ajalvir               0
# 2     1998                 3      Alameda del Valle               0
# 3     1998                 3      Alameda del Valle               0
# 4     1998                 5      Alcalá de Henares               0
# ...    ...               ...                    ...             ...
# 9383  2023               181   Villaviciosa de Odón               0
# 9384  2023               182  Villavieja del Lozoya               0
# 9385  2023               182  Villavieja del Lozoya               0
# 9386  2023               183              Zarzalejo               0
# 9387  2023               183              Zarzalejo               0
#
#              entidad_nombre fecha_festivo
# 0                   Ajalvir    1998-02-03
# 1                   Ajalvir    1998-05-15
# 2         Alameda del Valle    1998-02-02
# 3         Alameda del Valle    1998-09-08
# 4         Alcalá de Henares    1998-08-06
# ...                     ...           ...
# 9383   Villaviciosa de Odón    2023-09-18
# 9384  Villavieja del Lozoya    2023-08-21
# 9385  Villavieja del Lozoya    2023-12-07
# 9386              Zarzalejo    2023-06-29
# 9387              Zarzalejo    2023-09-08
#
# [9388 rows x 6 columns]

# %%
reg = pd.read_csv(path+"festivos_regionales_historicos.csv", sep=';', encoding = 'latin-1')
reg24 = pd.read_csv(path+"festivos_regionales.csv", sep=';', encoding = 'latin-1')

# Keep only regional data from 2020 and ahead
reg = reg[reg['año'] >= 2022]
reg
# Out:
#       año fecha_festivo                       festividad
# 309  2022    2022-01-01                        Año Nuevo
# 310  2022    2022-01-06               Epifanía del Señor
# 311  2022    2022-04-14                     Jueves Santo
# 312  2022    2022-04-15                    Viernes Santo
# 313  2022    2022-05-02       Fiesta Comunidad de Madrid
# 314  2022    2022-07-25                 Santiago Apóstol
# 315  2022    2022-08-15            Asunción de la Virgen
# 316  2022    2022-10-12        Fiesta Nacional de España
# 317  2022    2022-11-01                 Todos los Santos
# 318  2022    2022-12-06  Día de la Constitución Española
# 319  2022    2022-12-08            Inmaculada Concepción
# 320  2022    2022-12-26     Traslado Natividad del Señor
# 321  2023    2023-01-06               Epifanía del Señor
# 322  2023    2023-03-20                Traslado San José
# 323  2023    2023-04-06                     Jueves Santo
# 324  2023    2023-04-07                    Viernes Santo
# 325  2023    2023-05-01               Fiesta del Trabajo
# 326  2023    2023-05-02       Fiesta Comunidad de Madrid
# 327  2023    2023-08-15            Asunción de la Virgen
# 328  2023    2023-10-12        Fiesta Nacional de España
# 329  2023    2023-11-01                 Todos los Santos
# 330  2023    2023-12-06  Día de la Constitución Española
# 331  2023    2023-12-08            Inmaculada Concepción
# 332  2023    2023-12-25              Natividad del Señor

# %% [markdown]
# #### Transformation of Municipal data

# %%
loc = pd.read_csv(path+"festivos_locales_historicos.csv", sep=';', encoding = 'latin-1')
loc24 = pd.read_csv(path+"festivos_locales.csv", sep=';', encoding = 'latin-1')

# Keep only local data from Madrid and from 2020 or ahead
loc = loc[(loc['año'] >= 2020) & (loc['municipio_nombre'] == 'Madrid')]
loc24 = loc24[loc24['municipio_nombre'] == 'Madrid']
loc
# Out:
#        año  municipio_codigo municipio_nombre  entidad_codigo entidad_nombre  \
# 8142  2020                79           Madrid               0         Madrid
# 8143  2020                79           Madrid               0         Madrid
# 8494  2021                79           Madrid               0         Madrid
# 8495  2021                79           Madrid               0         Madrid
# 8846  2022                79           Madrid               0         Madrid
# 8847  2022                79           Madrid               0         Madrid
# 9200  2023                79           Madrid               0         Madrid
# 9201  2023                79           Madrid               0         Madrid
#
#      fecha_festivo
# 8142    2020-05-15
# 8143    2020-11-09
# 8494    2021-05-15
# 8495    2021-11-09
# 8846    2022-05-16
# 8847    2022-11-09
# 9200    2023-05-15
# 9201    2023-11-09

# %% [markdown]
# #### Merge holiday calendar data

# %%
all_holiday = pd.concat([reg,reg24,loc,loc24], ignore_index=True)

# create date id
all_holiday['holiday_id'] = all_holiday['fecha_festivo'].apply(lambda x: int(x.replace('-', '')))
# all_holiday.to_csv(f"{path}AllHoliday_df.csv", index=False)
all_holiday.sort_values(by='fecha_festivo').reset_index(drop=True)
# Out:
#      año fecha_festivo                           festividad  municipio_codigo  \
# 0   2020    2020-01-01                            Año Nuevo               NaN
# 1   2020    2020-01-06                   Epifanía del Señor               NaN
# 2   2020    2020-04-09                         Jueves Santo               NaN
# 3   2020    2020-04-10                        Viernes Santo               NaN
# 4   2020    2020-05-01                   Fiesta del Trabajo               NaN
# 5   2020    2020-05-02     Fiesta de la Comunidad de Madrid               NaN
# 6   2020    2020-05-15                                  NaN              79.0
# 7   2020    2020-08-15                Asunción de la Virgen               NaN
# 8   2020    2020-10-12            Fiesta Nacional de España               NaN
# 9   2020    2020-11-02            traslado Todos los Santos               NaN
# 10  2020    2020-11-09                                  NaN              79.0
# 11  2020    2020-12-07   traslado Día Constitución Española               NaN
# 12  2020    2020-12-08                Inmaculada Concepción               NaN
# 13  2020    2020-12-25                  Natividad del Señor               NaN
# 14  2021    2021-01-01                            Año Nuevo               NaN
# 15  2021    2021-01-06                   Epifanía del Señor               NaN
# 16  2021    2021-03-19                             San José               NaN
# 17  2021    2021-04-01                         Jueves Santo               NaN
# 18  2021    2021-04-02                        Viernes Santo               NaN
# 19  2021    2021-05-01                   Fiesta del Trabajo               NaN
# 20  2021    2021-05-03  traslado Fiesta Comunidad de Madrid               NaN
# 21  2021    2021-05-15                                  NaN              79.0
# 22  2021    2021-10-12            Fiesta Nacional de España               NaN
# 23  2021    2021-11-01                     Todos los Santos               NaN
# 24  2021    2021-11-09                                  NaN              79.0
# 25  2021    2021-12-06      Día de la Constitución Española               NaN
# 26  2021    2021-12-08                Inmaculada Concepción               NaN
# 27  2021    2021-12-25                  Natividad del Señor               NaN
# 28  2022    2022-01-01                            Año Nuevo               NaN
# 29  2022    2022-01-06                   Epifanía del Señor               NaN
# 30  2022    2022-04-14                         Jueves Santo               NaN
# 31  2022    2022-04-15                        Viernes Santo               NaN
# 32  2022    2022-05-02           Fiesta Comunidad de Madrid               NaN
# 33  2022    2022-05-16                                  NaN              79.0
# 34  2022    2022-07-25                     Santiago Apóstol               NaN
# 35  2022    2022-08-15                Asunción de la Virgen               NaN
# 36  2022    2022-10-12            Fiesta Nacional de España               NaN
# 37  2022    2022-11-01                     Todos los Santos               NaN
# 38  2022    2022-11-09                                  NaN              79.0
# 39  2022    2022-12-06      Día de la Constitución Española               NaN
# 40  2022    2022-12-08                Inmaculada Concepción               NaN
# 41  2022    2022-12-26         Traslado Natividad del Señor               NaN
# 42  2023    2023-01-06                   Epifanía del Señor               NaN
# 43  2023    2023-03-20                    Traslado San José               NaN
# 44  2023    2023-04-06                         Jueves Santo               NaN
# 45  2023    2023-04-07                        Viernes Santo               NaN
# 46  2023    2023-05-01                   Fiesta del Trabajo               NaN
# 47  2023    2023-05-02           Fiesta Comunidad de Madrid               NaN
# 48  2023    2023-05-15                                  NaN              79.0
# 49  2023    2023-08-15                Asunción de la Virgen               NaN
# 50  2023    2023-10-12            Fiesta Nacional de España               NaN
# 51  2023    2023-11-01                     Todos los Santos               NaN
# 52  2023    2023-11-09                                  NaN              79.0
# 53  2023    2023-12-06      Día de la Constitución Española               NaN
# 54  2023    2023-12-08                Inmaculada Concepción               NaN
# 55  2023    2023-12-25                  Natividad del Señor               NaN
# 56  2024    2024-01-01                            Año Nuevo               NaN
# 57  2024    2024-01-06                   Epifanía del Señor               NaN
# 58  2024    2024-03-28                         Jueves Santo               NaN
# 59  2024    2024-03-29                        Viernes Santo               NaN
# 60  2024    2024-05-01                   Fiesta del Trabajo               NaN
# 61  2024    2024-05-02           Fiesta Comunidad de Madrid               NaN
# 62  2024    2024-05-15                                  NaN              79.0
# 63  2024    2024-07-25                     Santiago Apóstol               NaN
# 64  2024    2024-08-15                Asunción de la Virgen               NaN
# 65  2024    2024-10-12            Fiesta Nacional de España               NaN
# 66  2024    2024-11-01                     Todos los Santos               NaN
# 67  2024    2024-11-09                                  NaN              79.0
# 68  2024    2024-12-06      Día de la Constitución Española               NaN
# 69  2024    2024-12-25                  Natividad del Señor               NaN
#
#    municipio_nombre  entidad_codigo entidad_nombre  holiday_id
# 0               NaN             NaN            NaN    20200101
# 1               NaN             NaN            NaN    20200106
# 2               NaN             NaN            NaN    20200409
# 3               NaN             NaN            NaN    20200410
# 4               NaN             NaN            NaN    20200501
# 5               NaN             NaN            NaN    20200502
# 6            Madrid             0.0         Madrid    20200515
# 7               NaN             NaN            NaN    20200815
# 8               NaN             NaN            NaN    20201012
# 9               NaN             NaN            NaN    20201102
# 10           Madrid             0.0         Madrid    20201109
# 11              NaN             NaN            NaN    20201207
# 12              NaN             NaN            NaN    20201208
# 13              NaN             NaN            NaN    20201225
# 14              NaN             NaN            NaN    20210101
# 15              NaN             NaN            NaN    20210106
# 16              NaN             NaN            NaN    20210319
# 17              NaN             NaN            NaN    20210401
# 18              NaN             NaN            NaN    20210402
# 19              NaN             NaN            NaN    20210501
# 20              NaN             NaN            NaN    20210503
# 21           Madrid             0.0         Madrid    20210515
# 22              NaN             NaN            NaN    20211012
# 23              NaN             NaN            NaN    20211101
# 24           Madrid             0.0         Madrid    20211109
# 25              NaN             NaN            NaN    20211206
# 26              NaN             NaN            NaN    20211208
# 27              NaN             NaN            NaN    20211225
# 28              NaN             NaN            NaN    20220101
# 29              NaN             NaN            NaN    20220106
# 30              NaN             NaN            NaN    20220414
# 31              NaN             NaN            NaN    20220415
# 32              NaN             NaN            NaN    20220502
# 33           Madrid             0.0         Madrid    20220516
# 34              NaN             NaN            NaN    20220725
# 35              NaN             NaN            NaN    20220815
# 36              NaN             NaN            NaN    20221012
# 37              NaN             NaN            NaN    20221101
# 38           Madrid             0.0         Madrid    20221109
# 39              NaN             NaN            NaN    20221206
# 40              NaN             NaN            NaN    20221208
# 41              NaN             NaN            NaN    20221226
# 42              NaN             NaN            NaN    20230106
# 43              NaN             NaN            NaN    20230320
# 44              NaN             NaN            NaN    20230406
# 45              NaN             NaN            NaN    20230407
# 46              NaN             NaN            NaN    20230501
# 47              NaN             NaN            NaN    20230502
# 48           Madrid             0.0         Madrid    20230515
# 49              NaN             NaN            NaN    20230815
# 50              NaN             NaN            NaN    20231012
# 51              NaN             NaN            NaN    20231101
# 52           Madrid             0.0         Madrid    20231109
# 53              NaN             NaN            NaN    20231206
# 54              NaN             NaN            NaN    20231208
# 55              NaN             NaN            NaN    20231225
# 56              NaN             NaN            NaN    20240101
# 57              NaN             NaN            NaN    20240106
# 58              NaN             NaN            NaN    20240328
# 59              NaN             NaN            NaN    20240329
# 60              NaN             NaN            NaN    20240501
# 61              NaN             NaN            NaN    20240502
# 62           Madrid             0.0         Madrid    20240515
# 63              NaN             NaN            NaN    20240725
# 64              NaN             NaN            NaN    20240815
# 65              NaN             NaN            NaN    20241012
# 66              NaN             NaN            NaN    20241101
# 67           Madrid             0.0         Madrid    20241109
# 68              NaN             NaN            NaN    20241206
# 69              NaN             NaN            NaN    20241225

# %% [markdown]
# ## Calendar dataset

# %%
import datetime as dt
calendar_df = pd.DataFrame({"date": pd.date_range('2022-01-01', '2024-12-31')})
calendar_df["day_month"] = calendar_df.date.dt.day
calendar_df["month"] = calendar_df.date.dt.month
calendar_df["year"] = calendar_df.date.dt.year
calendar_df["day_week"] = calendar_df.date.dt.day_name()
calendar_df["id_date"] = calendar_df.date.dt.strftime('%Y%m%d').astype('int')
calendar_df["date"] = calendar_df["date"].dt.strftime('%Y-%m-%d')
calendar_df
# Out:
#             date  day_month  month  year   day_week   id_date
# 0     2022-01-01          1      1  2022   Saturday  20220101
# 1     2022-01-02          2      1  2022     Sunday  20220102
# 2     2022-01-03          3      1  2022     Monday  20220103
# 3     2022-01-04          4      1  2022    Tuesday  20220104
# 4     2022-01-05          5      1  2022  Wednesday  20220105
# ...          ...        ...    ...   ...        ...       ...
# 1091  2024-12-27         27     12  2024     Friday  20241227
# 1092  2024-12-28         28     12  2024   Saturday  20241228
# 1093  2024-12-29         29     12  2024     Sunday  20241229
# 1094  2024-12-30         30     12  2024     Monday  20241230
# 1095  2024-12-31         31     12  2024    Tuesday  20241231
#
# [1096 rows x 6 columns]

# %% [markdown]
# #### Merge holiday data

# %%
all_holiday = pd.read_csv(path+"AllHoliday_df.csv")
merged_df = pd.merge(calendar_df, all_holiday['holiday_id'], left_on='id_date', right_on='holiday_id', how='left')

# Create flag holiday
merged_df['flg_holiday'] = (merged_df['holiday_id'].notnull()) | (merged_df['day_week'].str.contains('Saturday|Sunday'))
# Convert boolean values to int
merged_df['flg_holiday'] = merged_df['flg_holiday'].astype(int)
merged_df.drop(columns=['holiday_id'], inplace=True)
merged_df
# Out:
#             date  day_month  month  year   day_week   id_date  flg_holiday
# 0     2022-01-01          1      1  2022   Saturday  20220101            1
# 1     2022-01-02          2      1  2022     Sunday  20220102            1
# 2     2022-01-03          3      1  2022     Monday  20220103            0
# 3     2022-01-04          4      1  2022    Tuesday  20220104            0
# 4     2022-01-05          5      1  2022  Wednesday  20220105            0
# ...          ...        ...    ...   ...        ...       ...          ...
# 1091  2024-12-27         27     12  2024     Friday  20241227            0
# 1092  2024-12-28         28     12  2024   Saturday  20241228            1
# 1093  2024-12-29         29     12  2024     Sunday  20241229            1
# 1094  2024-12-30         30     12  2024     Monday  20241230            0
# 1095  2024-12-31         31     12  2024    Tuesday  20241231            0
#
# [1096 rows x 7 columns]

# %%
# Note: the calendar must be order for function shift
def get_day_type(row):
    if row['flg_holiday']:
        return 2
    elif merged_df['flg_holiday'].shift(1)[row.name]:  # Shift the entire 'holiday' column and access the value at the current row index
        return 1
    elif merged_df['flg_holiday'].shift(-1)[row.name]:
        return 1
    else:
        return 0

merged_df['day_type'] = merged_df.apply(get_day_type, axis=1)
merged_df
# Out:
#             date  day_month  month  year   day_week   id_date  flg_holiday  \
# 0     2022-01-01          1      1  2022   Saturday  20220101            1
# 1     2022-01-02          2      1  2022     Sunday  20220102            1
# 2     2022-01-03          3      1  2022     Monday  20220103            0
# 3     2022-01-04          4      1  2022    Tuesday  20220104            0
# 4     2022-01-05          5      1  2022  Wednesday  20220105            0
# ...          ...        ...    ...   ...        ...       ...          ...
# 1091  2024-12-27         27     12  2024     Friday  20241227            0
# 1092  2024-12-28         28     12  2024   Saturday  20241228            1
# 1093  2024-12-29         29     12  2024     Sunday  20241229            1
# 1094  2024-12-30         30     12  2024     Monday  20241230            0
# 1095  2024-12-31         31     12  2024    Tuesday  20241231            0
#
#       day_type
# 0            2
# 1            2
# 2            1
# 3            0
# 4            1
# ...        ...
# 1091         1
# 1092         2
# 1093         2
# 1094         1
# 1095         1
#
# [1096 rows x 8 columns]

# %%
# Remove flg_holiday column
merged_df.drop(columns=['flg_holiday'], inplace=True)

# Map the weekday names to numerical values
merged_df['day_week'] = merged_df['day_week'].str.strip()
weekday_mapping = {'Monday': 1,'Tuesday': 2,'Wednesday': 3,'Thursday': 4,'Friday': 5,'Saturday': 6,'Sunday': 7}
merged_df['day_week'] = merged_df['day_week'].map(weekday_mapping)

merged_df
# Out:
#             date  day_month  month  year  day_week   id_date  day_type
# 0     2022-01-01          1      1  2022         6  20220101         2
# 1     2022-01-02          2      1  2022         7  20220102         2
# 2     2022-01-03          3      1  2022         1  20220103         1
# 3     2022-01-04          4      1  2022         2  20220104         0
# 4     2022-01-05          5      1  2022         3  20220105         1
# ...          ...        ...    ...   ...       ...       ...       ...
# 1091  2024-12-27         27     12  2024         5  20241227         1
# 1092  2024-12-28         28     12  2024         6  20241228         2
# 1093  2024-12-29         29     12  2024         7  20241229         2
# 1094  2024-12-30         30     12  2024         1  20241230         1
# 1095  2024-12-31         31     12  2024         2  20241231         1
#
# [1096 rows x 7 columns]

# %% [markdown]
# #### Merge weather data

# %%
weather_df = pd.read_csv(path+"pastWeather20220101_20240410.csv")
weather_df
# Out:
#            date  weather_code  temperature_2m_max  temperature_2m_min  \
# 0    2022-01-01           3.0           15.602500              6.5025
# 1    2022-01-02           3.0           14.302500              6.8025
# 2    2022-01-03           3.0           13.102500              5.6525
# 3    2022-01-04          80.0           11.752500              4.6525
# 4    2022-01-05          51.0            7.952500              3.0025
# ..          ...           ...                 ...                 ...
# 826  2024-04-06           3.0           22.976000             10.7260
# 827  2024-04-07          51.0           21.226000             12.0760
# 828  2024-04-08          53.0           16.776000              7.1760
# 829  2024-04-09           0.0           14.976000              3.6260
# 830  2024-04-10           3.0           19.075998              3.9760
#
#      precipitation_sum
# 0                  0.0
# 1                  0.0
# 2                  0.0
# 3                  2.7
# 4                  0.6
# ..                 ...
# 826                0.0
# 827                0.4
# 828                0.6
# 829                0.0
# 830                0.0
#
# [831 rows x 5 columns]

# %%
merged_df2 = pd.merge(merged_df, weather_df, left_on='date', right_on='date', how='left')
# merged_df2.to_csv(f"{path}OpenData_CalendarAll_df.csv", index=False)
merged_df2
# Out:
#             date  day_month  month  year  day_week   id_date  day_type  \
# 0     2022-01-01          1      1  2022         6  20220101         2
# 1     2022-01-02          2      1  2022         7  20220102         2
# 2     2022-01-03          3      1  2022         1  20220103         1
# 3     2022-01-04          4      1  2022         2  20220104         0
# 4     2022-01-05          5      1  2022         3  20220105         1
# ...          ...        ...    ...   ...       ...       ...       ...
# 1091  2024-12-27         27     12  2024         5  20241227         1
# 1092  2024-12-28         28     12  2024         6  20241228         2
# 1093  2024-12-29         29     12  2024         7  20241229         2
# 1094  2024-12-30         30     12  2024         1  20241230         1
# 1095  2024-12-31         31     12  2024         2  20241231         1
#
#       weather_code  temperature_2m_max  temperature_2m_min  precipitation_sum
# 0              3.0             15.6025              6.5025                0.0
# 1              3.0             14.3025              6.8025                0.0
# 2              3.0             13.1025              5.6525                0.0
# 3             80.0             11.7525              4.6525                2.7
# 4             51.0              7.9525              3.0025                0.6
# ...            ...                 ...                 ...                ...
# 1091           NaN                 NaN                 NaN                NaN
# 1092           NaN                 NaN                 NaN                NaN
# 1093           NaN                 NaN                 NaN                NaN
# 1094           NaN                 NaN                 NaN                NaN
# 1095           NaN                 NaN                 NaN                NaN
#
# [1096 rows x 11 columns]
